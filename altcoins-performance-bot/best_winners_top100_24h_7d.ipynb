# %% [markdown]
# # Getting the best performing coins in BTC for the last 24h to 7 days.

# %% [markdown]
# ## Introduction

# %% [markdown]
# The motivation behind this is to screen constantly (daily) the altcoins market to get info about which coins are performing the best in bitcoin terms. These are the ones I want to look at and potentially invest in.
#
# The idea is to get a list of those, and to trigger an event to receive alerts either by email or on Slack.
#
# I programmed a script to get the list with price changes in bitcoin for the last 24h and 7d.

# %%
import pandas as pd
import plotly.graph_objects as go

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 24h price changes ranking

# %% [markdown]
# We can easily create a list of the best performing coins for the past 24 hours.
# Remember that we'll look at prices in bitcoin terms.

# %% [markdown]
# I'm using the [coingecko API](https://www.coingecko.com/api/documentations/v3#/), and the python wrapper [pycoingecko](https://pypi.org/project/pycoingecko/).

# %%
# The get_coins_market method gives a lot of info like current price, mkcap, price and mkcap change 24h, 
# price and mkcap percentage change 24h, high & low 24h, ...
crypto_100 = cg.get_coins_markets(vs_currency='btc')
df_top100 = pd.DataFrame(crypto_100, columns=['id', 'symbol', 'current_price', 'market_cap', 'market_cap_rank', 'price_change_percentage_24h'])
print(df_top100.info())
display(df_top100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
# id                             100 non-null object
# symbol                         100 non-null object
# current_price                  100 non-null float64
# market_cap                     100 non-null int64
# market_cap_rank                100 non-null int64
# price_change_percentage_24h    100 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 4.8+ KB
# None
#                            id  symbol  current_price  market_cap  \
# 0                     bitcoin     btc   1.000000e+00    18671287
# 1                    ethereum     eth   3.361458e-02     3871262
# 2                 binancecoin     bnb   5.926000e-03      914859
# 3                      tether    usdt   1.680000e-05      701777
# 4                     cardano     ada   2.027000e-05      647214
# 5                    polkadot     dot   6.367000e-04      624332
# 6                      ripple     xrp   9.670000e-06      443308
# 7                     uniswap     uni   4.919500e-04      255661
# 8                    litecoin     ltc   3.441790e-03      229767
# 9                    filecoin     fil   3.385980e-03      215017
# 10                  chainlink    link   5.094400e-04      211693
# 11                theta-token   theta   1.992900e-04      199474
# 12                   usd-coin    usdc   1.679000e-05      182663
# 13                    stellar     xlm   7.720000e-06      176294
# 14               bitcoin-cash     bch   9.356550e-03      174759
# 15            wrapped-bitcoin    wbtc   1.000815e+00      140111
# 16                   dogecoin    doge   9.873000e-07      127722
# 17                 terra-luna    luna   3.193400e-04      123762
# 18                       tron     trx   1.490000e-06      106798
# 19                    vechain     vet   1.510000e-06       97753
# 20           crypto-com-chain     cro   3.730000e-06       94160
# 21                        eos     eos   9.213000e-05       87760
# 22                     solana     sol   3.193200e-04       85627
# 23                       aave    aave   6.592300e-03       82185
# 24                        okb     okb   2.927200e-04       78933
# 25                     cosmos    atom   3.300000e-04       78725
# 26                     monero     xmr   4.261590e-03       76107
# 27                       iota   miota   2.649000e-05       73579
# 28            bitcoin-cash-sv     bsv   3.827220e-03       71530
# 29                     kusama     ksm   7.288910e-03       65226
# 30                      tezos     xtz   8.428000e-05       64432
# 31             compound-ether    ceth   6.727300e-04       63435
# 32                        neo     neo   8.950800e-04       63012
# 33                avalanche-2    AVAX   4.886600e-04       62476
# 34               bittorrent-2     btt   9.470000e-08       62388
# 35                  ftx-token     ftt   7.006000e-04       61901
# 36                binance-usd    busd   1.678000e-05       59296
# 37                   algorand    algo   2.239000e-05       58587
# 38                        nem     xem   6.120000e-06       57910
# 39                  holotoken     hot   3.000000e-07       53196
# 40                     havven     snx   3.457800e-04       51064
# 41                huobi-token      ht   2.795200e-04       50754
# 42                        dai     dai   1.680000e-05       49853
# 43          compound-usd-coin   cusdc   3.664000e-07       47786
# 44           hedera-hashgraph    hbar   5.870000e-06       46375
# 45               elrond-erd-2    egld   2.630040e-03       45832
# 46                     chiliz     chz   8.490000e-06       45535
# 47                       cdai    cdai   3.576000e-07       45155
# 48          pancakeswap-token    cake   3.014600e-04       44085
# 49                       dash    dash   3.979400e-03       39970
# 50                     decred     dcr   3.081470e-03       39307
# 51                  enjincoin     enj   4.133000e-05       38535
# 52                      maker     mkr   4.255259e-02       38320
# 53  compound-governance-token    comp   7.688090e-03       37208
# 54                      sushi   sushi   2.653100e-04       37192
# 55                  the-graph     grt   3.043000e-05       37165
# 56                    zilliqa     zil   3.080000e-06       36538
# 57                       near    near   9.990000e-05       33681
# 58                  leo-token     leo   3.409000e-05       32667
# 59                      zcash     zec   2.925290e-03       31967
# 60                  thorchain    rune   1.366500e-04       31632
# 61              matic-network   matic   6.250000e-06       31347
# 62       celsius-degree-token     cel   8.023000e-05       30815
# 63                    pundi-x    npxs   1.224000e-07       28957
# 64      basic-attention-token     bat   1.939000e-05       28874
# 65           ethereum-classic     etc   2.442600e-04       28354
# 66                  huobi-btc    hbtc   9.984245e-01       27862
# 67                    harmony     one   2.960000e-06       27775
# 68                   terrausd     ust   1.674000e-05       27623
# 69                  ravencoin     rvn   3.260000e-06       27595
# 70                       icon     icx   4.574000e-05       27185
# 71               mask-network    mask   4.386800e-04       27036
# 72                       nexo    nexo   4.714000e-05       26397
# 73                      ecomi     omi   1.503000e-07       24928
# 74                    siacoin      sc   5.185000e-07       24365
# 75                         0x     zrx   3.190000e-05       24200
# 76                        uma     uma   4.030900e-04       24122
# 77                   ontology     ont   2.950000e-05       23852
# 78                       dent    dent   2.478000e-07       23082
# 79                    arweave      ar   5.260800e-04       23068
# 80                 blockstack     stx   2.175000e-05       22845
# 81               decentraland    mana   1.694000e-05       22500
# 82              yearn-finance     yfi   6.191066e-01       22348
# 83                     bancor     bnt   1.275900e-04       22105
# 84                       ankr    ankr   2.990000e-06       20837
# 85                      waves   waves   1.981000e-04       19810
# 86       reserve-rights-token     rsr   1.490000e-06       19541
# 87                     fantom     ftm   7.570000e-06       19237
# 88                   digibyte     dgb   1.320000e-06       18746
# 89                  amp-token     amp   5.129000e-07       18604
# 90                       flow    flow   5.306400e-04       18040
# 91                     helium     hnt   2.346400e-04       17969
# 92                       bmax    btmx   2.356000e-05       17620
# 93                       qtum    qtum   1.698700e-04       17568
# 94                    omisego     omg   1.216300e-04       17068
# 95                   iostoken    iost   9.111000e-07       16929
# 96                     xsushi  xsushi   2.990400e-04       16893
# 97                  swissborg    chsb   1.753000e-05       16845
# 98                      ethos     vgx   7.465000e-05       16594
# 99             paxos-standard     pax   1.680000e-05       16518
#
#     market_cap_rank  price_change_percentage_24h
# 0                 1                      0.00000
# 1                 2                      2.67069
# 2                 3                     12.08958
# 3                 4                     -0.98888
# 4                 5                      0.05980
# 5                 6                     -0.24447
# 6                 7                      0.18731
# 7                 8                     -2.08441
# 8                 9                      3.24168
# 9                10                     -8.10778
# 10               11                      0.43961
# 11               12                     -2.75992
# 12               13                     -1.36024
# 13               14                     11.25679
# 14               15                      2.74276
# 15               16                     -0.01676
# 16               17                      5.82222
# 17               18                      1.18578
# 18               19                      1.34897
# 19               20                     -2.06323
# 20               21                      1.16568
# 21               22                     11.70039
# 22               23                     -6.12061
# 23               24                      2.87674
# 24               25                      5.30231
# 25               26                      0.67277
# 26               27                     -0.74111
# 27               28                     -0.85985
# 28               29                      2.84682
# 29               30                    -12.04006
# 30               31                     -0.27551
# 31               32                      2.69242
# 32               33                      2.07026
# 33               34                      0.36878
# 34               35                     11.60843
# 35               36                      2.89841
# 36               37                     -1.55052
# 37               38                     -4.37502
# 38               39                     -4.19512
# 39               40                      3.82172
# 40               41                     10.21529
# 41               42                      6.53306
# 42               43                     -1.04281
# 43               44                     -1.49736
# 44               45                     -3.36208
# 45               46                     11.03647
# 46               47                     -0.58804
# 47               48                     -1.49595
# 48               49                      0.07952
# 49               50                      3.74456
# 50               51                      0.33855
# 51               52                     -5.08194
# 52               53                      8.51993
# 53               54                      1.45621
# 54               55                      5.21565
# 55               56                      3.91506
# 56               57                      1.38380
# 57               58                     -2.11373
# 58               59                     -1.13647
# 59               60                     11.33723
# 60               61                     -8.45856
# 61               62                      0.05487
# 62               63                     -1.30361
# 63               64                     -6.65610
# 64               65                     -1.54685
# 65               66                      2.25499
# 66               67                     -0.03360
# 67               68                     -7.50061
# 68               69                     -1.43714
# 69               70                     -5.31965
# 70               71                     -7.82059
# 71               72                     47.57755
# 72               73                      0.07213
# 73               74                    -17.33490
# 74               75                     10.16144
# 75               76                     -5.09944
# 76               77                     -2.74824
# 77               78                     -3.35233
# 78               79                     11.75759
# 79               80                     -0.73437
# 80               81                      5.96960
# 81               82                     -2.06163
# 82               83                      1.50163
# 83               84                      0.23684
# 84               85                      9.87958
# 85               86                     -0.93431
# 86               87                     -2.36082
# 87               88                      7.28401
# 88               89                      1.47706
# 89               90                      1.70308
# 90               91                     -7.43530
# 91               92                     27.29826
# 92               93                     -7.14759
# 93               94                     -2.25671
# 94               95                     -7.61388
# 95               96                     -5.33544
# 96               97                      4.89950
# 97               98                     -8.96989
# 98               99                     -5.85777
# 99              100                     -1.32390

# %%
df_top100_best24h = df_top100.sort_values('price_change_percentage_24h', ascending=False)
display(df_top100_best24h)
# Out:
#                            id  symbol  current_price  market_cap  \
# 71               mask-network    mask   4.386800e-04       27036
# 91                     helium     hnt   2.346400e-04       17969
# 2                 binancecoin     bnb   5.926000e-03      914859
# 78                       dent    dent   2.478000e-07       23082
# 21                        eos     eos   9.213000e-05       87760
# 34               bittorrent-2     btt   9.470000e-08       62388
# 59                      zcash     zec   2.925290e-03       31967
# 13                    stellar     xlm   7.720000e-06      176294
# 45               elrond-erd-2    egld   2.630040e-03       45832
# 40                     havven     snx   3.457800e-04       51064
# 74                    siacoin      sc   5.185000e-07       24365
# 84                       ankr    ankr   2.990000e-06       20837
# 52                      maker     mkr   4.255259e-02       38320
# 87                     fantom     ftm   7.570000e-06       19237
# 41                huobi-token      ht   2.795200e-04       50754
# 80                 blockstack     stx   2.175000e-05       22845
# 16                   dogecoin    doge   9.873000e-07      127722
# 24                        okb     okb   2.927200e-04       78933
# 54                      sushi   sushi   2.653100e-04       37192
# 96                     xsushi  xsushi   2.990400e-04       16893
# 55                  the-graph     grt   3.043000e-05       37165
# 39                  holotoken     hot   3.000000e-07       53196
# 49                       dash    dash   3.979400e-03       39970
# 8                    litecoin     ltc   3.441790e-03      229767
# 35                  ftx-token     ftt   7.006000e-04       61901
# 23                       aave    aave   6.592300e-03       82185
# 28            bitcoin-cash-sv     bsv   3.827220e-03       71530
# 14               bitcoin-cash     bch   9.356550e-03      174759
# 31             compound-ether    ceth   6.727300e-04       63435
# 1                    ethereum     eth   3.361458e-02     3871262
# 65           ethereum-classic     etc   2.442600e-04       28354
# 32                        neo     neo   8.950800e-04       63012
# 89                  amp-token     amp   5.129000e-07       18604
# 82              yearn-finance     yfi   6.191066e-01       22348
# 88                   digibyte     dgb   1.320000e-06       18746
# 53  compound-governance-token    comp   7.688090e-03       37208
# 56                    zilliqa     zil   3.080000e-06       36538
# 18                       tron     trx   1.490000e-06      106798
# 17                 terra-luna    luna   3.193400e-04      123762
# 20           crypto-com-chain     cro   3.730000e-06       94160
# 25                     cosmos    atom   3.300000e-04       78725
# 10                  chainlink    link   5.094400e-04      211693
# 33                avalanche-2    AVAX   4.886600e-04       62476
# 50                     decred     dcr   3.081470e-03       39307
# 83                     bancor     bnt   1.275900e-04       22105
# 6                      ripple     xrp   9.670000e-06      443308
# 48          pancakeswap-token    cake   3.014600e-04       44085
# 72                       nexo    nexo   4.714000e-05       26397
# 4                     cardano     ada   2.027000e-05      647214
# 61              matic-network   matic   6.250000e-06       31347
# 0                     bitcoin     btc   1.000000e+00    18671287
# 15            wrapped-bitcoin    wbtc   1.000815e+00      140111
# 66                  huobi-btc    hbtc   9.984245e-01       27862
# 5                    polkadot     dot   6.367000e-04      624332
# 30                      tezos     xtz   8.428000e-05       64432
# 46                     chiliz     chz   8.490000e-06       45535
# 79                    arweave      ar   5.260800e-04       23068
# 26                     monero     xmr   4.261590e-03       76107
# 27                       iota   miota   2.649000e-05       73579
# 85                      waves   waves   1.981000e-04       19810
# 3                      tether    usdt   1.680000e-05      701777
# 42                        dai     dai   1.680000e-05       49853
# 58                  leo-token     leo   3.409000e-05       32667
# 62       celsius-degree-token     cel   8.023000e-05       30815
# 99             paxos-standard     pax   1.680000e-05       16518
# 12                   usd-coin    usdc   1.679000e-05      182663
# 68                   terrausd     ust   1.674000e-05       27623
# 47                       cdai    cdai   3.576000e-07       45155
# 43          compound-usd-coin   cusdc   3.664000e-07       47786
# 64      basic-attention-token     bat   1.939000e-05       28874
# 36                binance-usd    busd   1.678000e-05       59296
# 81               decentraland    mana   1.694000e-05       22500
# 19                    vechain     vet   1.510000e-06       97753
# 7                     uniswap     uni   4.919500e-04      255661
# 57                       near    near   9.990000e-05       33681
# 93                       qtum    qtum   1.698700e-04       17568
# 86       reserve-rights-token     rsr   1.490000e-06       19541
# 76                        uma     uma   4.030900e-04       24122
# 11                theta-token   theta   1.992900e-04      199474
# 77                   ontology     ont   2.950000e-05       23852
# 44           hedera-hashgraph    hbar   5.870000e-06       46375
# 38                        nem     xem   6.120000e-06       57910
# 37                   algorand    algo   2.239000e-05       58587
# 51                  enjincoin     enj   4.133000e-05       38535
# 75                         0x     zrx   3.190000e-05       24200
# 69                  ravencoin     rvn   3.260000e-06       27595
# 95                   iostoken    iost   9.111000e-07       16929
# 98                      ethos     vgx   7.465000e-05       16594
# 22                     solana     sol   3.193200e-04       85627
# 63                    pundi-x    npxs   1.224000e-07       28957
# 92                       bmax    btmx   2.356000e-05       17620
# 90                       flow    flow   5.306400e-04       18040
# 67                    harmony     one   2.960000e-06       27775
# 94                    omisego     omg   1.216300e-04       17068
# 70                       icon     icx   4.574000e-05       27185
# 9                    filecoin     fil   3.385980e-03      215017
# 60                  thorchain    rune   1.366500e-04       31632
# 97                  swissborg    chsb   1.753000e-05       16845
# 29                     kusama     ksm   7.288910e-03       65226
# 73                      ecomi     omi   1.503000e-07       24928
#
#     market_cap_rank  price_change_percentage_24h
# 71               72                     47.57755
# 91               92                     27.29826
# 2                 3                     12.08958
# 78               79                     11.75759
# 21               22                     11.70039
# 34               35                     11.60843
# 59               60                     11.33723
# 13               14                     11.25679
# 45               46                     11.03647
# 40               41                     10.21529
# 74               75                     10.16144
# 84               85                      9.87958
# 52               53                      8.51993
# 87               88                      7.28401
# 41               42                      6.53306
# 80               81                      5.96960
# 16               17                      5.82222
# 24               25                      5.30231
# 54               55                      5.21565
# 96               97                      4.89950
# 55               56                      3.91506
# 39               40                      3.82172
# 49               50                      3.74456
# 8                 9                      3.24168
# 35               36                      2.89841
# 23               24                      2.87674
# 28               29                      2.84682
# 14               15                      2.74276
# 31               32                      2.69242
# 1                 2                      2.67069
# 65               66                      2.25499
# 32               33                      2.07026
# 89               90                      1.70308
# 82               83                      1.50163
# 88               89                      1.47706
# 53               54                      1.45621
# 56               57                      1.38380
# 18               19                      1.34897
# 17               18                      1.18578
# 20               21                      1.16568
# 25               26                      0.67277
# 10               11                      0.43961
# 33               34                      0.36878
# 50               51                      0.33855
# 83               84                      0.23684
# 6                 7                      0.18731
# 48               49                      0.07952
# 72               73                      0.07213
# 4                 5                      0.05980
# 61               62                      0.05487
# 0                 1                      0.00000
# 15               16                     -0.01676
# 66               67                     -0.03360
# 5                 6                     -0.24447
# 30               31                     -0.27551
# 46               47                     -0.58804
# 79               80                     -0.73437
# 26               27                     -0.74111
# 27               28                     -0.85985
# 85               86                     -0.93431
# 3                 4                     -0.98888
# 42               43                     -1.04281
# 58               59                     -1.13647
# 62               63                     -1.30361
# 99              100                     -1.32390
# 12               13                     -1.36024
# 68               69                     -1.43714
# 47               48                     -1.49595
# 43               44                     -1.49736
# 64               65                     -1.54685
# 36               37                     -1.55052
# 81               82                     -2.06163
# 19               20                     -2.06323
# 7                 8                     -2.08441
# 57               58                     -2.11373
# 93               94                     -2.25671
# 86               87                     -2.36082
# 76               77                     -2.74824
# 11               12                     -2.75992
# 77               78                     -3.35233
# 44               45                     -3.36208
# 38               39                     -4.19512
# 37               38                     -4.37502
# 51               52                     -5.08194
# 75               76                     -5.09944
# 69               70                     -5.31965
# 95               96                     -5.33544
# 98               99                     -5.85777
# 22               23                     -6.12061
# 63               64                     -6.65610
# 92               93                     -7.14759
# 90               91                     -7.43530
# 67               68                     -7.50061
# 94               95                     -7.61388
# 70               71                     -7.82059
# 9                10                     -8.10778
# 60               61                     -8.45856
# 97               98                     -8.96989
# 29               30                    -12.04006
# 73               74                    -17.33490

# %% [markdown]
# ## 7 days price changes ranking

# %% [markdown]
# The get_coin_market_chart_by_id method gives hourly prices for the past x days if x < 90 days. <br/>
# Response format: lists of [timestamp, value] for price, mkcap, and volume. <br/>
# As inputs, we need the id of coins, the target currency, and the number of days to date back data.

# %%
# Fetching the date for which we want the price change
import time
from datetime import datetime, timedelta
today = time.strftime("%d/%m/%Y")
date = (datetime.now() - timedelta(7)).strftime('%d-%m-%Y')

# %%
# list of id for the top 100 coins
ids_list = df_top100['id'].tolist()
display(ids_list[0:5])
# Out:
# ['bitcoin', 'ethereum', 'binancecoin', 'tether', 'cardano']

# %% [markdown]
# The method `get_coin_market_chart_by_id` can't be used for multiple coins at once, so we'll need to do ethereum first and create a for loop to iterate on our ids_list.

# %% [markdown]
# #### First try with Ethereum

# %%
coin_data7d = cg.get_coin_market_chart_by_id(id='ethereum', vs_currency='btc', days=7)
coin_data7d = pd.DataFrame(coin_data7d)
coin_data7d = coin_data7d['prices']
coin_data7d = coin_data7d.to_frame() # we get a df of one column with [timestamp, prices] at each row. 
# splitting it in two columns
coin_data7d = pd.DataFrame(coin_data7d['prices'].to_list(), columns=['timestamp', 'prices'])
display(coin_data7d.head())
display(coin_data7d.info())
# Out:
#        timestamp    prices
# 0  1616746519034  0.030823
# 1  1616750343998  0.030363
# 2  1616754176875  0.030370
# 3  1616756552597  0.030419
# 4  1616761929341  0.030730
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 2 columns):
# timestamp    169 non-null int64
# prices       169 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 2.8 KB
# None

# %% [markdown]
# The response gives us hourly prices in BTC for the past 7 days. We'll need to take the mean of the first 24 prices (T-7), the last 24 prices (T0), and compute the change between them.

# %%
oldest_day = coin_data7d.head(24)
oldest_day_price_avg = oldest_day['prices'].mean()
print(oldest_day_price_avg)
mostrecent_day = coin_data7d.tail(24)
mostrecent_day_price_avg = mostrecent_day['prices'].mean()
print(mostrecent_day_price_avg)
# Out:
# 0.03083469908444654
# 0.03326518713536554

# %%
price_change_percentage_7d = ((mostrecent_day_price_avg - oldest_day_price_avg) / oldest_day_price_avg)*100
print(price_change_percentage_7d)
# Out:
# 7.882314804703161

# %% [markdown]
# #### Integrating that in a loop

# %%
# df to which we'll append our coins
df_top100_best7d = pd.DataFrame(columns=['id', 'price_change_percentage_7d'])

for id in ids_list:
    # step 1
    coin_data7d = cg.get_coin_market_chart_by_id(id=id, vs_currency='btc', days=7)
    coin_data7d = pd.DataFrame(coin_data7d)
    coin_data7d = coin_data7d['prices']
    coin_data7d = coin_data7d.to_frame() # we get a df of one column with [timestamp, prices] at each row. 
    # splitting it in two columns
    coin_data7d = pd.DataFrame(coin_data7d['prices'].to_list(), columns=['timestamp', 'prices'])
    
    # step 2
    oldest_day = coin_data7d.head(24)
    oldest_day_price_avg = oldest_day['prices'].mean()
    mostrecent_day = coin_data7d.tail(24)
    mostrecent_day_price_avg = mostrecent_day['prices'].mean()
    
    # step 3
    price_change_percentage_7d = ((mostrecent_day_price_avg - oldest_day_price_avg) / oldest_day_price_avg)*100

    # step 4: appending the data
    to_append = [[id, price_change_percentage_7d]]
    print(to_append)
    df_top100_best7d = df_top100_best7d.append(pd.DataFrame(to_append, columns=['id','price_change_percentage_7d']),ignore_index=True)
    time.sleep(1)
    
display(df_top100_best7d.info())
display(df_top100_best7d.head())
# Out:
# [['bitcoin', 0.0]]
# [['ethereum', 7.97328182098118]]
# [['binancecoin', 22.662492853326118]]
# [['tether', -8.245685627965532]]
# [['cardano', -9.140569902038271]]
# [['polkadot', 7.052721763322434]]
# [['ripple', -5.942161805064998]]
# [['uniswap', -6.527046870938764]]
# [['litecoin', 2.272456800886349]]
# [['filecoin', 57.18023242456929]]
# [['chainlink', 3.524956960594288]]
# [['theta-token', -12.455391987407783]]
# [['usd-coin', -8.2481686479536]]
# [['stellar', 4.205597027481271]]
# [['bitcoin-cash', 1.389907573543405]]
# [['wrapped-bitcoin', -0.009169999946273915]]
# [['dogecoin', 3.5569507234063047]]
# [['terra-luna', -7.870910894449495]]
# [['tron', 25.043720843571755]]
# [['vechain', -8.056648847710353]]
# [['crypto-com-chain', -3.3855238840204804]]
# [['eos', 20.968043686881682]]
# [['solana', 18.756470913479184]]
# [['aave', 0.6752325297971431]]
# [['okb', 24.459890013316272]]
# [['cosmos', -4.253146916512538]]
# [['monero', 4.995945913771887]]
# [['iota', 0.4525777619681441]]
# [['bitcoin-cash-sv', 3.7407556824185693]]
# [['kusama', -7.8228124294727515]]
# [['tezos', 10.912503105653808]]
# [['compound-ether', 7.965805412917221]]
# [['neo', 16.236348223047504]]
# [['avalanche-2', -6.864912000581621]]
# [['bittorrent-2', 45.06067795983414]]
# [['ftx-token', 6.63694873379501]]
# [['binance-usd', -8.251004936050508]]
# [['algorand', 10.182242029284202]]
# [['nem', -0.6745909471616679]]
# [['holotoken', 73.39592731135406]]
# [['havven', 2.1238898217765976]]
# [['huobi-token', 15.063704504167779]]
# [['dai', -8.359561311996965]]
# [['compound-usd-coin', -8.00384792622991]]
# [['hedera-hashgraph', -3.950185075680448]]
# [['elrond-erd-2', -1.717852274428758]]
# [['chiliz', -10.43163679348468]]
# [['cdai', -8.007933831159326]]
# [['pancakeswap-token', 8.888083968087125]]
# [['dash', 6.685798199255349]]
# [['decred', 7.772033064779007]]
# [['enjincoin', -0.45603435459495767]]
# [['maker', 10.241745514449216]]
# [['compound-governance-token', 11.969010337557656]]
# [['sushi', -15.28453547623283]]
# [['the-graph', 8.365478180125804]]
# [['zilliqa', -0.663306803417662]]
# [['near', 2.716710579795572]]
# [['leo-token', -12.227102131002377]]
# [['zcash', 17.11309668348981]]
# [['thorchain', 31.687154436432774]]
# [['matic-network', 0.5122443867745023]]
# [['celsius-degree-token', -10.502902569451432]]
# [['pundi-x', -17.392746623393702]]
# [['basic-attention-token', -0.3257640960714912]]
# [['ethereum-classic', 11.951565631670567]]
# [['huobi-btc', 0.15468258577838587]]
# [['harmony', -11.166122942173109]]
# [['terrausd', -8.098853501322685]]
# [['ravencoin', -11.126216461428077]]
# [['icon', 28.494747434140606]]
# [['mask-network', 91.62358301698191]]
# [['nexo', -1.6295704665463435]]
# [['ecomi', -14.381249445046357]]
# [['siacoin', 29.230840641050413]]
# [['0x', 27.246303382736592]]
# [['uma', -0.35825693329049507]]
# [['ontology', 23.439143094669735]]
# [['dent', 18.529935006608643]]
# [['arweave', 17.058708853486657]]
# [['blockstack', -4.8851925311024464]]
# [['decentraland', 4.581131945660087]]
# [['yearn-finance', 2.7733750526070593]]
# [['bancor', -3.465660606484206]]
# [['ankr', 17.74897725526369]]
# [['waves', -10.544099160989848]]
# [['reserve-rights-token', 0.1469823461449432]]
# [['fantom', 12.513264232802959]]
# [['digibyte', 9.249016209579192]]
# [['amp-token', 11.982506067338777]]
# [['flow', -0.6916461964269073]]
# [['helium', 39.52291026341543]]
# [['bmax', -45.57346406410378]]
# [['qtum', 9.0030728574318]]
# [['omisego', 27.744238011921503]]
# [['iostoken', 1.4604135890918646]]
# [['xsushi', -15.202843411182362]]
# [['swissborg', -19.9974326099663]]
# [['ethos', -20.27615639807098]]
# [['paxos-standard', -8.179341347213025]]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
# id                            100 non-null object
# price_change_percentage_7d    100 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB
# None
#             id  price_change_percentage_7d
# 0      bitcoin                    0.000000
# 1     ethereum                    7.973282
# 2  binancecoin                   22.662493
# 3       tether                   -8.245686
# 4      cardano                   -9.140570

# %%
df_top100_best7d = df_top100_best7d.sort_values('price_change_percentage_7d', ascending=False)
display(df_top100_best7d)
# Out:
#                            id  price_change_percentage_7d
# 71               mask-network                   91.623583
# 39                  holotoken                   73.395927
# 9                    filecoin                   57.180232
# 34               bittorrent-2                   45.060678
# 91                     helium                   39.522910
# 60                  thorchain                   31.687154
# 74                    siacoin                   29.230841
# 70                       icon                   28.494747
# 94                    omisego                   27.744238
# 75                         0x                   27.246303
# 18                       tron                   25.043721
# 24                        okb                   24.459890
# 77                   ontology                   23.439143
# 2                 binancecoin                   22.662493
# 21                        eos                   20.968044
# 22                     solana                   18.756471
# 78                       dent                   18.529935
# 84                       ankr                   17.748977
# 59                      zcash                   17.113097
# 79                    arweave                   17.058709
# 32                        neo                   16.236348
# 41                huobi-token                   15.063705
# 87                     fantom                   12.513264
# 89                  amp-token                   11.982506
# 53  compound-governance-token                   11.969010
# 65           ethereum-classic                   11.951566
# 30                      tezos                   10.912503
# 52                      maker                   10.241746
# 37                   algorand                   10.182242
# 88                   digibyte                    9.249016
# 93                       qtum                    9.003073
# 48          pancakeswap-token                    8.888084
# 55                  the-graph                    8.365478
# 1                    ethereum                    7.973282
# 31             compound-ether                    7.965805
# 50                     decred                    7.772033
# 5                    polkadot                    7.052722
# 49                       dash                    6.685798
# 35                  ftx-token                    6.636949
# 26                     monero                    4.995946
# 81               decentraland                    4.581132
# 13                    stellar                    4.205597
# 28            bitcoin-cash-sv                    3.740756
# 16                   dogecoin                    3.556951
# 10                  chainlink                    3.524957
# 82              yearn-finance                    2.773375
# 57                       near                    2.716711
# 8                    litecoin                    2.272457
# 40                     havven                    2.123890
# 95                   iostoken                    1.460414
# 14               bitcoin-cash                    1.389908
# 23                       aave                    0.675233
# 61              matic-network                    0.512244
# 27                       iota                    0.452578
# 66                  huobi-btc                    0.154683
# 86       reserve-rights-token                    0.146982
# 0                     bitcoin                    0.000000
# 15            wrapped-bitcoin                   -0.009170
# 64      basic-attention-token                   -0.325764
# 76                        uma                   -0.358257
# 51                  enjincoin                   -0.456034
# 56                    zilliqa                   -0.663307
# 38                        nem                   -0.674591
# 90                       flow                   -0.691646
# 72                       nexo                   -1.629570
# 45               elrond-erd-2                   -1.717852
# 20           crypto-com-chain                   -3.385524
# 83                     bancor                   -3.465661
# 44           hedera-hashgraph                   -3.950185
# 25                     cosmos                   -4.253147
# 80                 blockstack                   -4.885193
# 6                      ripple                   -5.942162
# 7                     uniswap                   -6.527047
# 33                avalanche-2                   -6.864912
# 29                     kusama                   -7.822812
# 17                 terra-luna                   -7.870911
# 43          compound-usd-coin                   -8.003848
# 47                       cdai                   -8.007934
# 19                    vechain                   -8.056649
# 68                   terrausd                   -8.098854
# 99             paxos-standard                   -8.179341
# 3                      tether                   -8.245686
# 12                   usd-coin                   -8.248169
# 36                binance-usd                   -8.251005
# 42                        dai                   -8.359561
# 4                     cardano                   -9.140570
# 46                     chiliz                  -10.431637
# 62       celsius-degree-token                  -10.502903
# 85                      waves                  -10.544099
# 69                  ravencoin                  -11.126216
# 67                    harmony                  -11.166123
# 58                  leo-token                  -12.227102
# 11                theta-token                  -12.455392
# 73                      ecomi                  -14.381249
# 96                     xsushi                  -15.202843
# 54                      sushi                  -15.284535
# 63                    pundi-x                  -17.392747
# 97                  swissborg                  -19.997433
# 98                      ethos                  -20.276156
# 92                       bmax                  -45.573464

# %%
df_top100 = pd.merge(df_top100_best24h, df_top100_best7d, on='id')
df_top100 = df_top100.sort_values('market_cap_rank')
display(df_top100.head())
# Out:
#              id symbol  current_price  market_cap  market_cap_rank  \
# 50      bitcoin    btc       1.000000    18671287                1
# 29     ethereum    eth       0.033615     3871262                2
# 2   binancecoin    bnb       0.005926      914859                3
# 60       tether   usdt       0.000017      701777                4
# 48      cardano    ada       0.000020      647214                5
#
#     price_change_percentage_24h  price_change_percentage_7d
# 50                      0.00000                    0.000000
# 29                      2.67069                    7.973282
# 2                      12.08958                   22.662493
# 60                     -0.98888                   -8.245686
# 48                      0.05980                   -9.140570

# %%
df_top100 = df_top100.set_index('market_cap_rank')
display(df_top100.head())
# Out:
#                           id symbol  current_price  market_cap  \
# market_cap_rank
# 1                    bitcoin    btc       1.000000    18671287
# 2                   ethereum    eth       0.033615     3871262
# 3                binancecoin    bnb       0.005926      914859
# 4                     tether   usdt       0.000017      701777
# 5                    cardano    ada       0.000020      647214
#
#                  price_change_percentage_24h  price_change_percentage_7d
# market_cap_rank
# 1                                    0.00000                    0.000000
# 2                                    2.67069                    7.973282
# 3                                   12.08958                   22.662493
# 4                                   -0.98888                   -8.245686
# 5                                    0.05980                   -9.140570

# %%
df_top100.sort_values('price_change_percentage_24h', ascending=False)
# Out:
#                                         id  symbol  current_price  market_cap  \
# market_cap_rank
# 72                            mask-network    mask   4.386800e-04       27036
# 92                                  helium     hnt   2.346400e-04       17969
# 3                              binancecoin     bnb   5.926000e-03      914859
# 79                                    dent    dent   2.478000e-07       23082
# 22                                     eos     eos   9.213000e-05       87760
# 35                            bittorrent-2     btt   9.470000e-08       62388
# 60                                   zcash     zec   2.925290e-03       31967
# 14                                 stellar     xlm   7.720000e-06      176294
# 46                            elrond-erd-2    egld   2.630040e-03       45832
# 41                                  havven     snx   3.457800e-04       51064
# 75                                 siacoin      sc   5.185000e-07       24365
# 85                                    ankr    ankr   2.990000e-06       20837
# 53                                   maker     mkr   4.255259e-02       38320
# 88                                  fantom     ftm   7.570000e-06       19237
# 42                             huobi-token      ht   2.795200e-04       50754
# 81                              blockstack     stx   2.175000e-05       22845
# 17                                dogecoin    doge   9.873000e-07      127722
# 25                                     okb     okb   2.927200e-04       78933
# 55                                   sushi   sushi   2.653100e-04       37192
# 97                                  xsushi  xsushi   2.990400e-04       16893
# 56                               the-graph     grt   3.043000e-05       37165
# 40                               holotoken     hot   3.000000e-07       53196
# 50                                    dash    dash   3.979400e-03       39970
# 9                                 litecoin     ltc   3.441790e-03      229767
# 36                               ftx-token     ftt   7.006000e-04       61901
# 24                                    aave    aave   6.592300e-03       82185
# 29                         bitcoin-cash-sv     bsv   3.827220e-03       71530
# 15                            bitcoin-cash     bch   9.356550e-03      174759
# 32                          compound-ether    ceth   6.727300e-04       63435
# 2                                 ethereum     eth   3.361458e-02     3871262
# 66                        ethereum-classic     etc   2.442600e-04       28354
# 33                                     neo     neo   8.950800e-04       63012
# 90                               amp-token     amp   5.129000e-07       18604
# 83                           yearn-finance     yfi   6.191066e-01       22348
# 89                                digibyte     dgb   1.320000e-06       18746
# 54               compound-governance-token    comp   7.688090e-03       37208
# 57                                 zilliqa     zil   3.080000e-06       36538
# 19                                    tron     trx   1.490000e-06      106798
# 18                              terra-luna    luna   3.193400e-04      123762
# 21                        crypto-com-chain     cro   3.730000e-06       94160
# 26                                  cosmos    atom   3.300000e-04       78725
# 11                               chainlink    link   5.094400e-04      211693
# 34                             avalanche-2    AVAX   4.886600e-04       62476
# 51                                  decred     dcr   3.081470e-03       39307
# 84                                  bancor     bnt   1.275900e-04       22105
# 7                                   ripple     xrp   9.670000e-06      443308
# 49                       pancakeswap-token    cake   3.014600e-04       44085
# 73                                    nexo    nexo   4.714000e-05       26397
# 5                                  cardano     ada   2.027000e-05      647214
# 62                           matic-network   matic   6.250000e-06       31347
# 1                                  bitcoin     btc   1.000000e+00    18671287
# 16                         wrapped-bitcoin    wbtc   1.000815e+00      140111
# 67                               huobi-btc    hbtc   9.984245e-01       27862
# 6                                 polkadot     dot   6.367000e-04      624332
# 31                                   tezos     xtz   8.428000e-05       64432
# 47                                  chiliz     chz   8.490000e-06       45535
# 80                                 arweave      ar   5.260800e-04       23068
# 27                                  monero     xmr   4.261590e-03       76107
# 28                                    iota   miota   2.649000e-05       73579
# 86                                   waves   waves   1.981000e-04       19810
# 4                                   tether    usdt   1.680000e-05      701777
# 43                                     dai     dai   1.680000e-05       49853
# 59                               leo-token     leo   3.409000e-05       32667
# 63                    celsius-degree-token     cel   8.023000e-05       30815
# 100                         paxos-standard     pax   1.680000e-05       16518
# 13                                usd-coin    usdc   1.679000e-05      182663
# 69                                terrausd     ust   1.674000e-05       27623
# 48                                    cdai    cdai   3.576000e-07       45155
# 44                       compound-usd-coin   cusdc   3.664000e-07       47786
# 65                   basic-attention-token     bat   1.939000e-05       28874
# 37                             binance-usd    busd   1.678000e-05       59296
# 82                            decentraland    mana   1.694000e-05       22500
# 20                                 vechain     vet   1.510000e-06       97753
# 8                                  uniswap     uni   4.919500e-04      255661
# 58                                    near    near   9.990000e-05       33681
# 94                                    qtum    qtum   1.698700e-04       17568
# 87                    reserve-rights-token     rsr   1.490000e-06       19541
# 77                                     uma     uma   4.030900e-04       24122
# 12                             theta-token   theta   1.992900e-04      199474
# 78                                ontology     ont   2.950000e-05       23852
# 45                        hedera-hashgraph    hbar   5.870000e-06       46375
# 39                                     nem     xem   6.120000e-06       57910
# 38                                algorand    algo   2.239000e-05       58587
# 52                               enjincoin     enj   4.133000e-05       38535
# 76                                      0x     zrx   3.190000e-05       24200
# 70                               ravencoin     rvn   3.260000e-06       27595
# 96                                iostoken    iost   9.111000e-07       16929
# 99                                   ethos     vgx   7.465000e-05       16594
# 23                                  solana     sol   3.193200e-04       85627
# 64                                 pundi-x    npxs   1.224000e-07       28957
# 93                                    bmax    btmx   2.356000e-05       17620
# 91                                    flow    flow   5.306400e-04       18040
# 68                                 harmony     one   2.960000e-06       27775
# 95                                 omisego     omg   1.216300e-04       17068
# 71                                    icon     icx   4.574000e-05       27185
# 10                                filecoin     fil   3.385980e-03      215017
# 61                               thorchain    rune   1.366500e-04       31632
# 98                               swissborg    chsb   1.753000e-05       16845
# 30                                  kusama     ksm   7.288910e-03       65226
# 74                                   ecomi     omi   1.503000e-07       24928
#
#                  price_change_percentage_24h  price_change_percentage_7d
# market_cap_rank
# 72                                  47.57755                   91.623583
# 92                                  27.29826                   39.522910
# 3                                   12.08958                   22.662493
# 79                                  11.75759                   18.529935
# 22                                  11.70039                   20.968044
# 35                                  11.60843                   45.060678
# 60                                  11.33723                   17.113097
# 14                                  11.25679                    4.205597
# 46                                  11.03647                   -1.717852
# 41                                  10.21529                    2.123890
# 75                                  10.16144                   29.230841
# 85                                   9.87958                   17.748977
# 53                                   8.51993                   10.241746
# 88                                   7.28401                   12.513264
# 42                                   6.53306                   15.063705
# 81                                   5.96960                   -4.885193
# 17                                   5.82222                    3.556951
# 25                                   5.30231                   24.459890
# 55                                   5.21565                  -15.284535
# 97                                   4.89950                  -15.202843
# 56                                   3.91506                    8.365478
# 40                                   3.82172                   73.395927
# 50                                   3.74456                    6.685798
# 9                                    3.24168                    2.272457
# 36                                   2.89841                    6.636949
# 24                                   2.87674                    0.675233
# 29                                   2.84682                    3.740756
# 15                                   2.74276                    1.389908
# 32                                   2.69242                    7.965805
# 2                                    2.67069                    7.973282
# 66                                   2.25499                   11.951566
# 33                                   2.07026                   16.236348
# 90                                   1.70308                   11.982506
# 83                                   1.50163                    2.773375
# 89                                   1.47706                    9.249016
# 54                                   1.45621                   11.969010
# 57                                   1.38380                   -0.663307
# 19                                   1.34897                   25.043721
# 18                                   1.18578                   -7.870911
# 21                                   1.16568                   -3.385524
# 26                                   0.67277                   -4.253147
# 11                                   0.43961                    3.524957
# 34                                   0.36878                   -6.864912
# 51                                   0.33855                    7.772033
# 84                                   0.23684                   -3.465661
# 7                                    0.18731                   -5.942162
# 49                                   0.07952                    8.888084
# 73                                   0.07213                   -1.629570
# 5                                    0.05980                   -9.140570
# 62                                   0.05487                    0.512244
# 1                                    0.00000                    0.000000
# 16                                  -0.01676                   -0.009170
# 67                                  -0.03360                    0.154683
# 6                                   -0.24447                    7.052722
# 31                                  -0.27551                   10.912503
# 47                                  -0.58804                  -10.431637
# 80                                  -0.73437                   17.058709
# 27                                  -0.74111                    4.995946
# 28                                  -0.85985                    0.452578
# 86                                  -0.93431                  -10.544099
# 4                                   -0.98888                   -8.245686
# 43                                  -1.04281                   -8.359561
# 59                                  -1.13647                  -12.227102
# 63                                  -1.30361                  -10.502903
# 100                                 -1.32390                   -8.179341
# 13                                  -1.36024                   -8.248169
# 69                                  -1.43714                   -8.098854
# 48                                  -1.49595                   -8.007934
# 44                                  -1.49736                   -8.003848
# 65                                  -1.54685                   -0.325764
# 37                                  -1.55052                   -8.251005
# 82                                  -2.06163                    4.581132
# 20                                  -2.06323                   -8.056649
# 8                                   -2.08441                   -6.527047
# 58                                  -2.11373                    2.716711
# 94                                  -2.25671                    9.003073
# 87                                  -2.36082                    0.146982
# 77                                  -2.74824                   -0.358257
# 12                                  -2.75992                  -12.455392
# 78                                  -3.35233                   23.439143
# 45                                  -3.36208                   -3.950185
# 39                                  -4.19512                   -0.674591
# 38                                  -4.37502                   10.182242
# 52                                  -5.08194                   -0.456034
# 76                                  -5.09944                   27.246303
# 70                                  -5.31965                  -11.126216
# 96                                  -5.33544                    1.460414
# 99                                  -5.85777                  -20.276156
# 23                                  -6.12061                   18.756471
# 64                                  -6.65610                  -17.392747
# 93                                  -7.14759                  -45.573464
# 91                                  -7.43530                   -0.691646
# 68                                  -7.50061                  -11.166123
# 95                                  -7.61388                   27.744238
# 71                                  -7.82059                   28.494747
# 10                                  -8.10778                   57.180232
# 61                                  -8.45856                   31.687154
# 98                                  -8.96989                  -19.997433
# 30                                 -12.04006                   -7.822812
# 74                                 -17.33490                  -14.381249

# %% [markdown]
# ## Conclusion
